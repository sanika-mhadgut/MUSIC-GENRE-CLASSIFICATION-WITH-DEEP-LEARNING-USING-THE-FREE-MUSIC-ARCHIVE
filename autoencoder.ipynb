# %% [markdown]
# # [FMA: A Dataset For Music Analysis](https://github.com/mdeff/fma)
#
# Michaël Defferrard, Kirell Benzi, Pierre Vandergheynst, Xavier Bresson, EPFL LTS2.
#
# ## Usage
#
# 1. Go through the [paper] to understand what the data is about.
# 1. Download some datasets from <https://github.com/mdeff/fma>.
# 1. Uncompress the archives, e.g. with `unzip fma_small.zip`.
# 1. Load and play with the data in this notebook.
#
# [paper]: https://arxiv.org/abs/1612.01840

# %%
import torch

# %%
# !git clone https://github.com/mdeff/fma.git
# !cd fma
# Out:
# fatal: destination path 'fma' already exists and is not an empty directory.

# %%
# !python --version
# Out:
# Python 3.11.7

# %%
# !pip install blosc2==2.0.0  # Example of resolving the tables dependency
# !pip install pyqt5<5.16 pyqtwebengine<5.16  # For Spyder compatibility
# !pip install black --upgrade  # Ensure you have a compatible version for python-lsp-black
# Out:
# ...
# zsh:1: no such file or directory: 5.16
# ...

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install numpy>=1.21.0  # Updated version for Python 3.11
# !pip install -r requirements.txt  # Make sure this file is updated first
# Out:
# ...
# zsh:1: 1.21.0 not found
# ...

# %%
# %matplotlib inline

import os

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display

import utils

plt.rcParams['figure.figsize'] = (17, 5)

# %%
os.environ['AUDIO_DIR']='fma_small' # the path to a decompressed fma_*.zip

# %%
# Directory where mp3 are stored.
AUDIO_DIR = os.environ.get('AUDIO_DIR')

# Load metadata and features.
tracks = utils.load('data/fma_metadata/tracks.csv')
genres = utils.load('data/fma_metadata/genres.csv')
features = utils.load('data/fma_metadata/features.csv')
echonest = utils.load('data/fma_metadata/echonest.csv')

np.testing.assert_array_equal(features.index, tracks.index)
assert echonest.index.isin(tracks.index).all()

tracks.shape, genres.shape, features.shape, echonest.shape
# Out:
# ((106574, 52), (163, 4), (106574, 518), (13129, 249))

# %% [markdown]
# ## 1 Metadata
#
# The metadata table, a CSV file in the `fma_metadata.zip` archive, is composed of many colums:
# 1. The index is the ID of the song, taken from the website, used as the name of the audio file.
# 2. Per-track, per-album and per-artist metadata from the Free Music Archive website.
# 3. Two columns to indicate the subset (small, medium, large) and the split (training, validation, test).

# %%
ipd.display(tracks['track'].head())
ipd.display(tracks['album'].head())
ipd.display(tracks['artist'].head())
ipd.display(tracks['set'].head())
# Out:
#           bit_rate  comments   composer        date_created date_recorded  \
# track_id
# 2           256000         0        NaN 2008-11-26 01:48:12    2008-11-26
# 3           256000         0        NaN 2008-11-26 01:48:14    2008-11-26
# 5           256000         0        NaN 2008-11-26 01:48:20    2008-11-26
# 10          192000         0  Kurt Vile 2008-11-25 17:49:06    2008-11-26
# 20          256000         0        NaN 2008-11-26 01:48:56    2008-01-01
#
#           duration  favorites genre_top     genres         genres_all  \
# track_id
# 2              168          2   Hip-Hop       [21]               [21]
# 3              237          1   Hip-Hop       [21]               [21]
# 5              206          6   Hip-Hop       [21]               [21]
# 10             161        178       Pop       [10]               [10]
# 20             311          0       NaN  [76, 103]  [17, 10, 76, 103]
#
#          information  interest language_code  \
# track_id
# ...

# %% [markdown]
# ### 1.1 Subsets
#
# The small and medium subsets can be selected with the below code.

# %%
small = tracks[tracks['set', 'subset'] <= 'small']
small.shape
# Out:
# (8000, 52)

# %%
medium = tracks[tracks['set', 'subset'] <= 'medium']
medium.shape
# Out:
# (25000, 52)

# %% [markdown]
# ## 2 Genres
#
# The genre hierarchy is stored in `genres.csv` and distributed in `fma_metadata.zip`.

# %%
print('{} top-level genres'.format(len(genres['top_level'].unique())))
genres.loc[genres['top_level'].unique()].sort_values('#tracks', ascending=False)
# Out:
# 16 top-level genres
#           #tracks  parent                title  top_level
# genre_id
# 38          38154       0         Experimental         38
# 15          34413       0           Electronic         15
# 12          32923       0                 Rock         12
# 1235        14938       0         Instrumental       1235
# 10          13845       0                  Pop         10
# 17          12706       0                 Folk         17
# 21           8389       0              Hip-Hop         21
# 2            5271       0        International          2
# 4            4126       0                 Jazz          4
# 5            4106       0            Classical          5
# 9            1987       0              Country          9
# 20           1876       0               Spoken         20
# 3            1752       0                Blues          3
# 14           1499       0             Soul-RnB         14
# 8             868       0  Old-Time / Historic          8
# ...

# %%
genres.sort_values('#tracks').head(10)
# Out:
#           #tracks  parent                     title  top_level
# genre_id
# 175             0      86                 Bollywood          2
# 178             0       4                    Be-Bop          4
# 377             1      19                 Deep Funk         14
# 173             4      86     N. Indian Traditional          2
# 493             4     651             Western Swing          9
# 374             9      20                    Banter         20
# 808            12      46                     Salsa          2
# 174            17      86  South Indian Traditional          2
# 465            18      20           Musical Theater         20
# 176            23       2                   Pacific          2

# %% [markdown]
# ## 3 Features
#
# 1. Features extracted from the audio for all tracks.
# 2. For some tracks, data colected from the [Echonest](http://the.echonest.com/) API.

# %%
print('{1} features for {0} tracks'.format(*features.shape))
columns = ['mfcc', 'chroma_cens', 'tonnetz', 'spectral_contrast']
columns.append(['spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff'])
columns.append(['rmse', 'zcr'])
for column in columns:
    ipd.display(features[column].head().style.format('{:.2f}'))
# Out:
# 518 features for 106574 tracks
# <style type="text/css">
# </style>
# <table id="T_2a21e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >statistics</th>
#       <th id="T_2a21e_level0_col0" class="col_heading level0 col0" colspan="20">kurtosis</th>
#       <th id="T_2a21e_level0_col20" class="col_heading level0 col20" colspan="20">max</th>
#       <th id="T_2a21e_level0_col40" class="col_heading level0 col40" colspan="20">mean</th>
#       <th id="T_2a21e_level0_col60" class="col_heading level0 col60" colspan="20">median</th>
#       <th id="T_2a21e_level0_col80" class="col_heading level0 col80" colspan="20">min</th>
#       <th id="T_2a21e_level0_col100" class="col_heading level0 col100" colspan="20">skew</th>
#       <th id="T_2a21e_level0_col120" class="col_heading level0 col120" colspan="20">std</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >number</th>
#       <th id="T_2a21e_level1_col0" class="col_heading level1 col0" >01</th>
# ...

# %% [markdown]
# ### 3.1 Echonest features

# %%
print('{1} features for {0} tracks'.format(*echonest.shape))
ipd.display(echonest['echonest', 'metadata'].head())
ipd.display(echonest['echonest', 'audio_features'].head())
ipd.display(echonest['echonest', 'social_features'].head())
ipd.display(echonest['echonest', 'ranks'].head())
# Out:
# 249 features for 13129 tracks
#           album_date         album_name  artist_latitude  \
# track_id
# 2                NaN                NaN          32.6783
# 3                NaN                NaN          32.6783
# 5                NaN                NaN          32.6783
# 10        2008-03-11  Constant Hitmaker          39.9523
# 134              NaN                NaN          32.6783
#
#                artist_location  artist_longitude artist_name  \
# track_id
# 2                  Georgia, US          -83.2230        AWOL
# 3                  Georgia, US          -83.2230        AWOL
# 5                  Georgia, US          -83.2230        AWOL
# 10        Philadelphia, PA, US          -75.1624   Kurt Vile
# 134                Georgia, US          -83.2230        AWOL
#
#                        release
# track_id
# 2         AWOL - A Way Of Life
# 3         AWOL - A Way Of Life
# 5         AWOL - A Way Of Life
# 10           Constant Hitmaker
# ...

# %%
ipd.display(echonest['echonest', 'temporal_features'].head())
x = echonest.loc[2, ('echonest', 'temporal_features')]
plt.plot(x);
# Out:
#                000       001       002       003       004       005  \
# track_id
# 2         0.877233  0.588911  0.354243  0.295090  0.298413  0.309430
# 3         0.534429  0.537414  0.443299  0.390879  0.344573  0.366448
# 5         0.548093  0.720192  0.389257  0.344934  0.361300  0.402543
# 10        0.311404  0.711402  0.321914  0.500601  0.250963  0.321316
# 134       0.610849  0.569169  0.428494  0.345796  0.376920  0.460590
#
#                006       007       008       009  ...       214        215  \
# track_id                                          ...
# 2         0.304496  0.334579  0.249495  0.259656  ... -1.992303   6.805694
# 3         0.419455  0.747766  0.460901  0.392379  ... -1.582331   8.889308
# 5         0.434044  0.388137  0.512487  0.525755  ... -2.288358  11.527109
# 10        0.734250  0.325188  0.373012  0.235840  ... -3.662988  21.508228
# 134       0.401371  0.449900  0.428946  0.446736  ... -1.452696   2.356398
#
# ...

# %% [markdown]
# ### 3.2 Features like MFCCs are discriminant

# %%
small = tracks['set', 'subset'] <= 'small'
genre1 = tracks['track', 'genre_top'] == 'Instrumental'
genre2 = tracks['track', 'genre_top'] == 'Hip-Hop'

X = features.loc[small & (genre1 | genre2), 'mfcc']
X = skl.decomposition.PCA(n_components=2).fit_transform(X)

y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
y = skl.preprocessing.LabelEncoder().fit_transform(y)

plt.scatter(X[:,0], X[:,1], c=y, cmap='RdBu', alpha=0.5)
X.shape, y.shape
# Out:
# ((2000, 2), (2000,))

# %% [markdown]
# ## 4 Audio
#
# You can load the waveform and listen to audio in the notebook itself.

# %%
print(AUDIO_DIR)
# Out:
# fma_small

# %%
filename = utils.get_audio_path(AUDIO_DIR, 2)
print('File: {}'.format(filename))

x, sr = librosa.load(filename, sr=None, mono=True)
print('Duration: {:.2f}s, {} samples'.format(x.shape[-1] / sr, x.size))

start, end = 7, 17
ipd.Audio(data=x[start*sr:end*sr], rate=sr)
# Out:
# File: fma_small/000/000002.mp3
# Duration: 29.98s, 1321967 samples
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# And use [librosa](https://github.com/librosa/librosa) to compute spectrograms and audio features.

# %%
# !pip install --upgrade librosa

# %%
librosa.display.waveshow(x);
plt.vlines([start, end], -1, 1)

start = len(x) // 2
plt.figure()
plt.plot(x[start:start+2000])
plt.ylim((-1, 1));

# %%
stft = np.abs(librosa.stft(x, n_fft=2048, hop_length=512))
mel = librosa.feature.melspectrogram(sr=sr, S=stft**2)
log_mel = librosa.amplitude_to_db(mel)

librosa.display.specshow(log_mel, sr=sr, hop_length=512, x_axis='time', y_axis='mel');

# %%
mfcc = librosa.feature.mfcc(S=librosa.power_to_db(mel), n_mfcc=20)
mfcc = skl.preprocessing.StandardScaler().fit_transform(mfcc)
librosa.display.specshow(mfcc, sr=sr, x_axis='time');

# %% [markdown]
# ## 5 Genre classification

# %% [markdown]
# ### 5.1 From features

# %%
small = tracks['set', 'subset'] <= 'small'

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[small & train, ('track', 'genre_top')]
y_test = tracks.loc[small & test, ('track', 'genre_top')]
X_train = features.loc[small & train, 'mfcc']
X_test = features.loc[small & test, 'mfcc']

print('{} training examples, {} testing examples'.format(y_train.size, y_test.size))
print('{} features, {} classes'.format(X_train.shape[1], np.unique(y_train).size))
# Out:
# 6400 training examples, 800 testing examples
# 140 features, 8 classes

# %%
# Be sure training samples are shuffled.
X_train, y_train = skl.utils.shuffle(X_train, y_train, random_state=42)

# Standardize features by removing the mean and scaling to unit variance.
scaler = skl.preprocessing.StandardScaler(copy=False)
scaler.fit_transform(X_train)
scaler.transform(X_test)

# Support vector classification.
clf = skl.svm.SVC()
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
print('Accuracy: {:.2%}'.format(score))
# Out:
# Accuracy: 46.38%

# %% [markdown]
# ### 5.2 From audio

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# # autoencoder

# %%
import numpy as np
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset
import pandas as pd
import torch.nn as nn

class MusicDataset(Dataset):
    def __init__(self, features, labels):
        label_encoder = LabelEncoder()
        labels_encoded = label_encoder.fit_transform(labels)

        self.features = torch.tensor(features.to_numpy(), dtype=torch.float32) if isinstance(features, pd.DataFrame) else torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels_encoded, dtype=torch.long)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

train_dataset = MusicDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
autoencoder_losses = []

class Autoencoder(nn.Module):
    def __init__(self, input_size):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_size, 256),
            nn.LeakyReLU(0.1),
            nn.Linear(256, 128),
            nn.LeakyReLU(0.1),
            nn.Linear(128, 64),
            nn.LeakyReLU(0.1),
            nn.Linear(64, 32)
       )

        self.decoder = nn.Sequential(
            nn.Linear(32, 64),
            nn.LeakyReLU(0.1),
            nn.Linear(64, 128),
            nn.LeakyReLU(0.1),
            nn.Linear(128, 256),
            nn.LeakyReLU(0.1),
            nn.Linear(256, input_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

autoencoder = Autoencoder(input_size=X_train.shape[1])

optimizer = torch.optim.Adam(autoencoder.parameters(), lr=0.003)
criterion = nn.MSELoss()
num_epochs = 50

for epoch in range(num_epochs):
    total_loss = 0
    for inputs, _ in train_loader:
        inputs = inputs.to(device)
        optimizer.zero_grad()
        outputs = autoencoder(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    avg_loss = total_loss / len(train_loader)
    autoencoder_losses.append(avg_loss)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}')
# Out:
# Epoch [1/50], Loss: 0.9421
# Epoch [2/50], Loss: 0.8538
# Epoch [3/50], Loss: 0.8215
# Epoch [4/50], Loss: 0.7965
# Epoch [5/50], Loss: 0.7857
# Epoch [6/50], Loss: 0.7745
# Epoch [7/50], Loss: 0.7654
# Epoch [8/50], Loss: 0.7567
# Epoch [9/50], Loss: 0.7522
# Epoch [10/50], Loss: 0.7467
# Epoch [11/50], Loss: 0.7413
# Epoch [12/50], Loss: 0.7389
# Epoch [13/50], Loss: 0.7367
# Epoch [14/50], Loss: 0.7333
# Epoch [15/50], Loss: 0.7320
# Epoch [16/50], Loss: 0.7284
# Epoch [17/50], Loss: 0.7265
# Epoch [18/50], Loss: 0.7244
# Epoch [19/50], Loss: 0.7239
# Epoch [20/50], Loss: 0.7233
# Epoch [21/50], Loss: 0.7207
# Epoch [22/50], Loss: 0.7202
# Epoch [23/50], Loss: 0.7200
# Epoch [24/50], Loss: 0.7169
# Epoch [25/50], Loss: 0.7162
# Epoch [26/50], Loss: 0.7151
# Epoch [27/50], Loss: 0.7150
# Epoch [28/50], Loss: 0.7138
# Epoch [29/50], Loss: 0.7145
# Epoch [30/50], Loss: 0.7125
# Epoch [31/50], Loss: 0.7090
# Epoch [32/50], Loss: 0.7093
# Epoch [33/50], Loss: 0.7079
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
label_encoder.fit(np.concatenate([y_train, y_test]))

y_test_encoded = label_encoder.transform(y_test)

y_test_tensor = torch.tensor(y_test_encoded, dtype=torch.long)

X_test_tensor = torch.tensor(X_test.to_numpy(), dtype=torch.float32) if isinstance(X_test, pd.DataFrame) else torch.tensor(X_test, dtype=torch.float32)
X_test_tensor = X_test_tensor.to(device)

autoencoder.eval()
with torch.no_grad():
    X_test_encoded = autoencoder.encoder(X_test_tensor)

# %%
encoded_test_dataset = TensorDataset(X_test_encoded, y_test_tensor)
encoded_test_loader = DataLoader(encoded_test_dataset, batch_size=32, shuffle=False)

# %%
class EncodedDataset(Dataset):
    def __init__(self, dataset, encoder):
        super(EncodedDataset, self).__init__()
        self.features = []
        self.labels = []
        self.encoder = encoder
        with torch.no_grad():
            for i in range(len(dataset)):
                feature, label = dataset[i]
                feature = feature.unsqueeze(0)
                encoded_feature = encoder(feature)
                self.features.append(encoded_feature.squeeze(0))
                self.labels.append(label)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

encoded_train_dataset = EncodedDataset(train_dataset, autoencoder.encoder)
encoded_train_loader = DataLoader(encoded_train_dataset, batch_size=32, shuffle=True)

# %%
classifier_losses = []
classifier_accuracies = []

class Classifier(nn.Module):
    def __init__(self, num_features, num_classes):
        super(Classifier, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(num_features,50),
            nn.BatchNorm1d(50),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(50, num_classes)
        )
    def forward(self, x):
        return self.layers(x)

num_features = 32
num_classes = len(np.unique(y_train))
classifier = Classifier(num_features, num_classes).to(device)

classifier_optimizer = torch.optim.Adam(classifier.parameters(), lr=0.005, weight_decay=0.01)
classifier_criterion = nn.CrossEntropyLoss()

for epoch in range(30):
    epoch_loss = 0
    correct = 0
    total = 0
    for features, labels in encoded_train_loader:
        features, labels = features.to(device), labels.to(device)
        classifier_optimizer.zero_grad()
        outputs = classifier(features)
        loss = classifier_criterion(outputs, labels)
        loss.backward()
        classifier_optimizer.step()
        epoch_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    epoch_accuracy = 100 * correct / total
    avg_loss = epoch_loss / len(encoded_train_loader)
    classifier_losses.append(avg_loss)
    classifier_accuracies.append(epoch_accuracy)
    print(f'Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%')
# Out:
# Epoch 1, Loss: 1.7003, Accuracy: 38.73%
# Epoch 2, Loss: 1.6071, Accuracy: 41.45%
# Epoch 3, Loss: 1.6052, Accuracy: 42.61%
# Epoch 4, Loss: 1.6047, Accuracy: 42.14%
# Epoch 5, Loss: 1.5870, Accuracy: 42.88%
# Epoch 6, Loss: 1.5935, Accuracy: 42.38%
# Epoch 7, Loss: 1.5948, Accuracy: 43.30%
# Epoch 8, Loss: 1.5916, Accuracy: 42.97%
# Epoch 9, Loss: 1.5830, Accuracy: 43.11%
# Epoch 10, Loss: 1.5963, Accuracy: 42.67%
# Epoch 11, Loss: 1.5920, Accuracy: 42.38%
# Epoch 12, Loss: 1.5839, Accuracy: 43.33%
# Epoch 13, Loss: 1.5825, Accuracy: 43.41%
# Epoch 14, Loss: 1.5926, Accuracy: 42.67%
# Epoch 15, Loss: 1.5933, Accuracy: 43.53%
# Epoch 16, Loss: 1.5946, Accuracy: 42.88%
# Epoch 17, Loss: 1.5849, Accuracy: 42.75%
# Epoch 18, Loss: 1.5800, Accuracy: 43.11%
# Epoch 19, Loss: 1.5948, Accuracy: 42.86%
# Epoch 20, Loss: 1.5864, Accuracy: 42.84%
# Epoch 21, Loss: 1.5846, Accuracy: 43.11%
# Epoch 22, Loss: 1.5731, Accuracy: 44.12%
# Epoch 23, Loss: 1.5915, Accuracy: 42.38%
# ...

# %%
def evaluate_model(model, data_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data in data_loader:
            inputs, labels = data
            print("Processing a new batch")
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            print(f"Batch processed, Total: {total}, Correct: {correct}")

    accuracy = 100 * correct / total
    print(f'Accuracy: {accuracy:.2f}%')

# %%
classifier.to(device)
evaluate_model(classifier, encoded_test_loader)
# Out:
# Processing a new batch
# Batch processed, Total: 32, Correct: 4
# Processing a new batch
# Batch processed, Total: 64, Correct: 9
# Processing a new batch
# Batch processed, Total: 96, Correct: 18
# Processing a new batch
# Batch processed, Total: 128, Correct: 34
# Processing a new batch
# Batch processed, Total: 160, Correct: 46
# Processing a new batch
# Batch processed, Total: 192, Correct: 59
# Processing a new batch
# Batch processed, Total: 224, Correct: 83
# Processing a new batch
# Batch processed, Total: 256, Correct: 88
# Processing a new batch
# Batch processed, Total: 288, Correct: 102
# Processing a new batch
# Batch processed, Total: 320, Correct: 112
# Processing a new batch
# Batch processed, Total: 352, Correct: 126
# Processing a new batch
# Batch processed, Total: 384, Correct: 139
# Processing a new batch
# Batch processed, Total: 416, Correct: 152
# Processing a new batch
# Batch processed, Total: 448, Correct: 158
# Processing a new batch
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(autoencoder_losses, label='Autoencoder Loss')
plt.title('Autoencoder Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(classifier_losses, label='Classifier Loss')
plt.title('Classifier Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(classifier_accuracies, label='Classifier Accuracy')
plt.title('Classifier Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
